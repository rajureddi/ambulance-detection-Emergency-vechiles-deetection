# %%
import zipfile
import os

zip_path = '/content/VehiclesDetectionDataset.zip'  # Replace with your actual file name
extract_path = 'vechiles_dataset'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Files extracted to: {extract_path}")
# Out:
# Files extracted to: vechiles_dataset

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('yolov8s.pt')

# Start training
# Note: In Colab, training on the GPU is much faster.
# Go to Runtime > Change runtime type > T4 GPU
results = model.train(
    data='/content/vechiles_dataset/VehiclesDetectionDataset/dataset.yaml',
    epochs=50,
    patience=50,
    batch=16,

    name='ambulance_detector_final'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO('yolov8s.pt') # Use 'n' for speed, 's' for better accuracy

results = model.train(
    data='/content/vechiles_dataset/VehiclesDetectionDataset/dataset.yaml',
    epochs=100,      # High limit, but patience will stop it early
    patience=50,     # Stop early if no improvement
    batch=16,        # Stable for T4 GPU
    imgsz=640,       # Standard resolution for traffic detection
    save=True,       # Saves best.pt automatically
    device=0,        # Forces use of the T4 GPU
    optimizer='auto', # Let YOLO pick (usually AdamW or SGD)
    name='ambulance_detector'

)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# -r means "recursive" to include all subfolders and files
# !zip -r /content/ambulance_results_final.zip /content/runs/detect/
# Out:
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/ambulance_detector/ (stored 0%)
#   adding: content/runs/detect/ambulance_detector/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/ambulance_detector/results.png (deflated 6%)
#   adding: content/runs/detect/ambulance_detector/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/ambulance_detector/BoxF1_curve.png (deflated 10%)
#   adding: content/runs/detect/ambulance_detector/train_batch6930.jpg (deflated 5%)
#   adding: content/runs/detect/ambulance_detector/val_batch2_labels.jpg (deflated 11%)
#   adding: content/runs/detect/ambulance_detector/labels.jpg (deflated 27%)
#   adding: content/runs/detect/ambulance_detector/confusion_matrix.png (deflated 25%)
#   adding: content/runs/detect/ambulance_detector/confusion_matrix_normalized.png (deflated 20%)
#   adding: content/runs/detect/ambulance_detector/val_batch2_pred.jpg (deflated 10%)
# ...

# %%
import os
from ultralytics import YOLO

# Get the absolute path to your current directory
dataset_path = os.path.join(os.getcwd(),'ambulance_dataset/data.yaml')

model = YOLO('yolov8n.pt')

results = model.train(
    data=dataset_path, # Using the full path helps avoid the "datasets" folder error
    epochs=50,
    imgsz=640,
    batch=16,
    name='ambulance_detector'
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.4/810.4 kB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 34.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load your best weights
model = YOLO('/content/best.pt')

# Run prediction on a TRAINING image (pick one you know has an ambulance)
# We set conf=0.1 to see even "weak" detections
results = model.predict(source='/content/images.jpg', conf=0.1)

# Show the result
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    cv2_imshow(im_array)
# Out:
# image 1/1 /content/images.jpg: 384x640 2 Ambulances, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.0 MB/s eta 0:00:00
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alkanerturan/vehicledetection")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'vehicledetection' dataset.
# Path to dataset files: /kaggle/input/vehicledetection

# %%
/root/.cache/kagglehub/datasets/alkanerturan/vehicledetection

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YdBeJNbLZoJcgKMwVHLk")
project = rf.workspace("ambulance-uj5pi").project("ambulance-sjpea")
version = project.version(20)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 134.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Ambulance-20 in yolov11:: 100%|██████████| 17886/17886 [00:02<00:00, 6147.04it/s]

# %%
# !pip install ultralytics
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YdBeJNbLZoJcgKMwVHLk")
project = rf.workspace("ambulance-detection-8kzlt").project("indian-emergency-vehicles-l2dju")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 80.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("amrutasalagare/vehicle-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'vehicle-dataset' dataset.
# Path to dataset files: /kaggle/input/vehicle-dataset

# %%
from ultralytics import YOLO

# Load base model (important choice)
model = YOLO("yolov8s.pt")
# model = YOLO("yolov8s.pt") # better accuracy
# model = YOLO("yolov8m.pt") # heavier but stronger


model.train(
    data="/content/Indian-emergency-vehicles-1/data.yaml",
    epochs=50,
        # VERY IMPORTANT
    batch=16,
    patience=50,        # early stopping
    degrees=10,         # augmentation
    scale=0.5,
    fliplr=0.5,
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
cd /content/Indian-emergency-vehicles-1
# Out:
# /content/Indian-emergency-vehicles-1

# %%
from google.colab import files
files.download('/content/Indian-emergency-vehicles-1/runs/detect/train2/weights/best.pt')   # change filename if needed
